# %% [markdown]
# # Antutu benchmark on Android

# %% [markdown]
# The goal of this experiment is to run benchmarks on a hikey960 board running Android with an IPA kernel and collect results. The analysis phase will consist in comparing IPA summary with:
#
# The benchmark we will be using is ***Antutu 3Dbench*** (http://www.antutu.com/en). You will need to **manually install** the app on the Android device in order to run this Notebook.
#
# the goals of this notebook:
# 1. Check different thermal behaviour for different workload or configuration
# 1. Compare the real power usage of SOC for different workload or configuration.

# %%
import logging
from conf import LisaLogging
LisaLogging.setup()
# Out:
# 2017-11-29 11:05:24,533 INFO    : root         : Using LISA logging configuration:
# 2017-11-29 11:05:24,570 INFO    : root         :   /home/steven/lisa/lisa-github/logging.conf

# %%
# %pylab inline

import copy
import os
from time import sleep
from subprocess import Popen
import pandas as pd

# Support to access the remote target
import devlib
from env import TestEnv

# Support for trace events analysis
from trace import Trace

# Suport for FTrace events parsing and visualization
import trappy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Test environment setup
#
# For more details on this please check out **examples/utils/testenv_example.ipynb**.

# %% [markdown]
# In case more than one Android device are conencted to the host, you must specify the ID of the device you want to target in `my_target_conf`. Run `adb devices` on your host to get the ID. Also, you have to specify the path to your android sdk in ANDROID_HOME.

# %%
# Setup a target configuration
my_target_conf = {
    
#     # Target platform and board
#     "platform"    : 'android',

#     # Add target support
#     "board" : 'pixel',
    
#     # Device ID
#     "device" : "HT6670300102",
    
#     "ANDROID_HOME" : "/home/vagrant/lisa/tools/android-sdk-linux/",
    
    "platform"    : 'android',
    "board"       : "hikey960",
    "device" : "0123456789ABCDEF",
    
    "ANDROID_HOME" : "/home/lisa/android-sdk",
    "rtapp-calib" : {"0": 302, "1": 302, "2": 304, "3": 304, "4": 136, "5": 137, "6": 136, "7": 136},

     "emeter" : {
        "instrument" : "acme",
        "conf" : {
            # Absolute path to the iio-capture binary on the host
            'iio-capture' : '/usr/bin/iio-capture',
            # Default host name of the BeagleBone Black
            'ip_address'     : '10.169.36.36',
        },
        "channel_map" : {
            "Device0" : 0, # iio:device0
            "Device1" : 1, # iio:device0
        }
    },
    
    # FTrace events to collect for all the tests configuration which have
    # the "ftrace" flag enabled
    "ftrace"  : {
         "events" : [
            "sched_switch",
            "cpu_capacity",
            "cpu_frequency",
            "thermal_power_devfreq_limit",
            "thermal_power_devfreq_get_power",
            "thermal_power_cpu_limit",
            "thermal_power_cpu_get_power",
            "thermal_zone_trip",
            "cdev_update",
            "thermal_temperature",
            "thermal_power_allocator_pid",
            "thermal_power_allocator",
         ],
         "buffsize" : 100 * 1024,
    },

    # Tools required by the experiments
    "tools"   : [ 'trace-cmd', 'taskset'],
    
    # Define devlib modules to load
    "modules"     : [
        'cpufreq'       # enable CPUFreq support
    ],
}

# %%
my_tests_conf = {

    # Folder where all the results will be collected
    "results_dir" : "Android_Antutu3_sustainable",

    # Platform configurations to test
    "confs" : [
        {
            "tag"            : "antutu",
            "flags"          : "ftrace",           # Enable FTrace events
            "sched_features" : "ENERGY_AWARE",     # enable EAS
        },
    ],
}

# %%
# Initialize a test environment using:
# the provided target configuration (my_target_conf)
# the provided test configuration   (my_test_conf)
te = TestEnv(target_conf=my_target_conf, test_conf=my_tests_conf)
target = te.target
# Out:
# 2017-11-29 11:05:32,142 INFO    : TestEnv      : Using base path: /home/steven/lisa/lisa-github
# 2017-11-29 11:05:32,144 INFO    : TestEnv      : Loading custom (inline) target configuration
# 2017-11-29 11:05:32,145 INFO    : TestEnv      : Loading custom (inline) test configuration
# 2017-11-29 11:05:32,147 INFO    : TestEnv      : External tools using:
# 2017-11-29 11:05:32,148 INFO    : TestEnv      :    ANDROID_HOME: /home/steven/lisa/android-sdk
# 2017-11-29 11:05:32,149 INFO    : TestEnv      :    CATAPULT_HOME: /home/steven/lisa/lisa-github/tools/catapult
# 2017-11-29 11:05:32,150 INFO    : TestEnv      : Devlib modules to load: ['bl', 'cpuidle', 'cpufreq']
# 2017-11-29 11:05:32,151 INFO    : TestEnv      : Connecting Android target [0123456789ABCDEF]
# 2017-11-29 11:05:32,152 INFO    : TestEnv      : Connection settings:
# 2017-11-29 11:05:32,153 INFO    : TestEnv      :    {'device': '0123456789ABCDEF'}
# 2017-11-29 11:05:34,439 INFO    : TestEnv      : Initializing target workdir:
# 2017-11-29 11:05:34,441 INFO    : TestEnv      :    /data/local/tmp/devlib-target
# 2017-11-29 11:05:36,683 INFO    : TestEnv      : Attempting to read energy model from target
# 2017-11-29 11:05:37,992 INFO    : TestEnv      : Topology:
# 2017-11-29 11:05:37,994 INFO    : TestEnv      :    [[0, 1, 2, 3], [4, 5, 6, 7]]
# 2017-11-29 11:05:38,184 INFO    : TestEnv      : Loading default EM:
# 2017-11-29 11:05:38,186 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/libs/utils/platforms/hikey960.json
# 2017-11-29 11:05:39,040 INFO    : TestEnv      : Enabled tracepoints:
# 2017-11-29 11:05:39,041 INFO    : TestEnv      :    sched_switch
# 2017-11-29 11:05:39,042 INFO    : TestEnv      :    cpu_capacity
# 2017-11-29 11:05:39,043 INFO    : TestEnv      :    cpu_frequency
# 2017-11-29 11:05:39,044 INFO    : TestEnv      :    thermal_power_devfreq_limit
# 2017-11-29 11:05:39,045 INFO    : TestEnv      :    thermal_power_devfreq_get_power
# 2017-11-29 11:05:39,046 INFO    : TestEnv      :    thermal_power_cpu_limit
# 2017-11-29 11:05:39,047 INFO    : TestEnv      :    thermal_power_cpu_get_power
# 2017-11-29 11:05:39,048 INFO    : TestEnv      :    thermal_zone_trip
# 2017-11-29 11:05:39,049 INFO    : TestEnv      :    cdev_update
# 2017-11-29 11:05:39,050 INFO    : TestEnv      :    thermal_temperature
# 2017-11-29 11:05:39,051 INFO    : TestEnv      :    thermal_power_allocator_pid
# 2017-11-29 11:05:39,052 INFO    : TestEnv      :    thermal_power_allocator
# 2017-11-29 11:05:39,053 INFO    : EnergyMeter  : ACME configuration:
# 2017-11-29 11:05:39,054 INFO    : EnergyMeter  :     binary: /usr/bin/iio-capture
# 2017-11-29 11:05:39,055 INFO    : EnergyMeter  :     device: 10.169.36.36
# 2017-11-29 11:05:39,056 INFO    : EnergyMeter  :   channels:
# 2017-11-29 11:05:39,057 INFO    : EnergyMeter  :      Device1 (iio:device1)
# 2017-11-29 11:05:39,058 INFO    : EnergyMeter  :      Device0 (iio:device0)
# 2017-11-29 11:05:39,110 INFO    : TestEnv      : Set results folder to:
# 2017-11-29 11:05:39,112 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/results/Android_Antutu3_sustainable
# 2017-11-29 11:05:39,113 INFO    : TestEnv      : Experiment results available also in:
# 2017-11-29 11:05:39,115 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/results_latest

# %% [markdown]
# ## Support Functions

# %% [markdown]
# This set of support functions will help us running the benchmark using different CPUFreq governors.

# %%
def set_test1():
    target.cpufreq.set_all_governors('schedutil')
    target.execute('echo 4500 > /sys/class/thermal/thermal_zone0/sustainable_power')
    print target.read_value('/sys/class/thermal/thermal_zone0/sustainable_power')

def set_test2():
    target.execute('echo 2500 > /sys/class/thermal/thermal_zone0/sustainable_power')
    print target.read_value('/sys/class/thermal/thermal_zone0/sustainable_power')

# %%
# CPUFreq configurations to test
confs = {
#     'performance' : {
#         'label' : 'prf',
#         'set' :  set_performance,
#     },
    #'powersave' : {
    #    'label' : 'pws',
    #    'set' :  set_powersave,
    #},
#      'interactive' : {
#          'label' : 'int',
#          'set' :  set_interactive,
#      },
    'test1' : {
       'label' : 'test1',
       'set' :  set_test1,
    },
    'test2' : {
       'label' : 'test2',
       'set' :  set_test2,
    },
    #'ondemand' : {
    #    'label' : 'odm',
    #    'set' :  set_ondemand,
    #}
}

# The set of results for each comparison test
results = {}

# %%
#Check if PCMark si available on the device

def check_packages(pkgname):
    try:
        output = target.execute('pm list packages -f | grep -i {}'.format(pkgname))
    except Exception:
        raise RuntimeError('Package: [{}] not availabe on target'.format(pkgname))

# Check for specified PKG name being available on target
check_packages('com.antutu.ABenchMark')
target.adb_root(force=True)

# %%
set_test1()
# Out:
# 4500

# %%
from android import Screen

target.execute('am force-stop {}'.format("com.antutu.ABenchMark"))
target.execute('input keyevent 4')
Screen.set_orientation(target, auto=False, portrait=True)
Screen.set_brightness(target, auto=False, percent=0)
target.cpufreq.set_all_governors('schedutil')

# Start PCMark on the target device
#target.execute('monkey --pct-syskeys 0 -p com.antutu.ABenchMark -c android.intent.category.LAUNCHER 1')
# Wait few seconds to make sure the app is loaded
# Screen.set_orientation(target, auto=False, portrait=True)
#sleep(10)
#target.execute('input tap 961 202')
# Wait few seconds to make sure the app is loaded
# sleep(5)
    

# Run performance workload (assume screen is vertical)
# Out:
# 2017-11-28 13:38:28,851 INFO    : Screen       : Force manual orientation
# 2017-11-28 13:38:28,853 INFO    : Screen       : Set orientation: PORTRAIT
# 2017-11-28 13:38:30,297 INFO    : Screen       : Set brightness: 0%
# ''

# %%
# Function that helps run a Antutu experiment
from android import Screen
from devlib.utils.android import adb_command

def benchmark_run(exp_dir):
    # Unlock device screen (assume no password required)
    target.execute('am force-stop {}'.format("com.antutu.ABenchMark"))
    target.execute('input keyevent 82')
    Screen.set_brightness(target, auto=False, percent=0)

    # Start PCMark on the target device
    target.execute('monkey --pct-syskeys 0 -p com.antutu.ABenchMark  1')
#     Screen.set_orientation(target, auto=False, portrait=True)

    # Wait few seconds to make sure the app is loaded
    sleep(5)
    
    # Flush entire log
    target.clear_logcat()
    target.execute('input tap 860 1000')
    sleep(1)
    Screen.set_orientation(target, auto=False, portrait=True)
    # Run performance workload (assume screen is vertical)
    target.execute('input tap 960 200')
    # Wait for completion (10 minutes in total) and collect log
#     log_file = os.path.join(exp_dir, 'log.txt')
    # Wait 5 minutes
    sleep(400)
    # Start collecting the log
#     with open(log_file, 'w') as log:
#         logcat = Popen(['adb logcat', 'com.antutu.ABenchMark.VirtualMachineState:*', '*:S'],
#                        stdout=log,
#                        shell=True)
#         # Wait additional two minutes for benchmark to complete
#         sleep(300)

#         # Terminate logcat
#         logcat.kill()

#     # Get scores from logcat
#     score_file = os.path.join(exp_dir, 'score.txt')
#     os.popen('grep -o ".*_SCORE .*" {} | sed "s/ = / /g" | sort -u > {}'.format(log_file, score_file))
    
    # Close application
    adb_command(target.adb_name, 'shell screencap -p /data/local/tmp/screen.png')
    adb_command(target.adb_name, 'pull /data/local/tmp/screen.png {}'.format(te.res_dir))
    target.execute('am force-stop com.antutu.ABenchMark')
    target.execute('am force-stop com.antutu.benchmark.full')

# %%
# Function that helps run PCMark for different governors

def experiment(governor, exp_dir):
    os.system('mkdir -p {}'.format(exp_dir));
    trace_file = os.path.join(exp_dir, 'trace.dat')

    logging.info('------------------------')
    logging.info('Run workload using %s governor', governor)
    confs[governor]['set']()

    ### Run the benchmark ###
    te.ftrace.start()

    benchmark_run(exp_dir)
    
    te.ftrace.stop()
    te.ftrace.get_trace(trace_file)

    # return all the experiment data
    return {
        'dir'        : exp_dir,
    }

# %% [markdown]
# ## Run Antutu and collect scores

# %%
# Run the benchmark in all the configured governors
testresult_list=[]
for testname in confs:
    test_dir = os.path.join(te.res_dir, testname)
    res = experiment(testname, test_dir)
    testresult_list.append(test_dir)
    print test_dir
# Out:
# 2017-11-29 11:11:21,221 INFO    : root         : ------------------------
# 2017-11-29 11:11:21,223 INFO    : root         : Run workload using test1 governor
# 2017-11-29 11:11:25,399 INFO    : Screen       : Set brightness: 0%
# 2017-11-29 11:11:32,381 INFO    : Screen       : Force manual orientation
# 2017-11-29 11:11:32,383 INFO    : Screen       : Set orientation: PORTRAIT
# 2017-11-29 11:18:23,655 INFO    : root         : ------------------------
# 2017-11-29 11:18:23,657 INFO    : root         : Run workload using test2 governor
# /home/steven/lisa/lisa-github/results/Android_Antutu3_sustainable/test1
# 2017-11-29 11:18:27,836 INFO    : Screen       : Set brightness: 0%
# 2017-11-29 11:18:34,783 INFO    : Screen       : Force manual orientation
# 2017-11-29 11:18:34,785 INFO    : Screen       : Set orientation: PORTRAIT
# /home/steven/lisa/lisa-github/results/Android_Antutu3_sustainable/test2

# %% [markdown]
# After running the benchmark for the specified governors we can show and plot the scores:

# %%
# Create results DataFrame
data = {}
data['test1'] = {}
data['test1']['total'] = 95847
data['test1']['3D'] = 23104
data['test1']['UX'] = 34621
data['test1']['CPU'] = 29103
data['test1']['RAM'] = 9013

data['test2'] = {}
data['test2']['total'] = 94341
data['test2']['3D'] = 22146
data['test2']['UX'] = 34466
data['test2']['CPU'] = 28587
data['test2']['RAM'] = 9142


df = pd.DataFrame.from_dict(data)
df
# Out:
#        test1  test2
# 3D     23104  22146
# CPU    29103  28587
# RAM     9013   9142
# UX     34621  34466
# total  95847  94341

# %%
df.plot(kind='bar', rot=45, figsize=(16,8),
        title='ANtutu scores Performance vs SchedFreq governors');

# %%
map_label = {"00000000,000000f0": "big", "00000000,0000000f": "LITTLE"}
actor_order = ["GPU", "big", "LITTLE"]
runs = [("test1", os.path.join(te.res_dir, 'test1', 'trace.dat')), ("test2", os.path.join(te.res_dir, 'test2', 'trace.dat'))]

# %%
runs
# Out:
# [('test1',
#   '/home/steven/lisa/lisa-github/results/Android_Antutu3_sustainable/test1/trace.dat'),
#  ('test2',
#   '/home/steven/lisa/lisa-github/results/Android_Antutu3_sustainable/test2/trace.dat')]

# %%
# te.ftrace.get_trace(te.res_dir)
te.ftrace.report(os.path.join(te.res_dir, 'test1', 'trace.dat'), os.path.join(te.res_dir, 'test1', 'trace.txt'))
te.ftrace.report(os.path.join(te.res_dir, 'test2', 'trace.dat'), os.path.join(te.res_dir, 'test2', 'trace.txt'))

# %%
# !tree {te.res_dir}
# Out:
# /home/steven/lisa/lisa-github/results/Android_Antutu3_sustainable
# ├── screen.png
# ├── test1
# │   ├── trace.dat
# │   └── trace.txt
# └── test2
#     ├── trace.dat
#     └── trace.txt
#
# 2 directories, 5 files

# %%
testresult_list
# Out:
# '/home/steven/lisa/lisa-github/results/Android_Antutu/sched'

# %%
trappy.compare_runs(actor_order, map_label, runs)

# %%
ftrace1=trappy.FTrace(name='sustainable power', path=os.path.join(te.res_dir, 'test1', 'trace.dat'), scope="thermal")
ftrace2=trappy.FTrace(name='sustainable power', path=os.path.join(te.res_dir, 'test2', 'trace.dat'), scope="thermal")

# %%
ftrace.thermal_governor.data_frame
# trappy.plot_utils.plot_input_power([ftrace1, ftrace2],actor_order)
# trappy.ILinePlot(ftrace, signals=["cpu_in_power:power", "cpu_out_power:power"]).view()
# ftrace.cpu_out_power.data_frame['freq'].plot()
# Out:
#                  __comm  __cpu   __line  __pid  current_temperature  \
# Time
# 3.999744    kworker/4:1      4    28248    612                78325
# 4.100439    kworker/4:1      4    30435    612                86308
# 4.199914    kworker/4:1      4    31784    612                74435
# 4.299902    kworker/4:1      4    33593    612                77710
# 4.399920    kworker/4:1      4    34898    612                75459
# 4.503867    kworker/4:1      4    36755    612                75459
# 4.603894    kworker/4:1      4    38374    612                75049
# 4.703961    kworker/4:1      4    40431    612                77096
# 4.803839    kworker/4:1      4    42237    612                74026
# 4.903913    kworker/4:1      4    44061    612                75459
# 5.003857    kworker/4:1      4    45005    612                73616
# 5.103859    kworker/4:1      4    46102    612                79553
# 5.203800    kworker/4:1      4    46973    612                77710
# 5.303893    kworker/4:1      4    48059    612                75663
# 5.403912    kworker/4:1      4    48623    612                73821
# 5.507768    kworker/4:1      4    49218    612                73207
# 5.607850    kworker/4:1      4    49698    612                72797
# 5.707896    kworker/4:1      4    50037    612                70136
# 6.807804    kworker/4:1      4    53667    612                80167
# 6.907786    kworker/4:1      4    54368    612                74435
# 7.011768    kworker/4:1      4    54975    612                75459
# 7.111850    kworker/4:1      4    55496    612                74026
# 7.211847    kworker/4:1      4    56034    612                73821
# 7.311778    kworker/4:1      4    56598    612                75049
# 7.415827    kworker/4:1      4    57202    612                74230
# 7.515817    kworker/4:1      4    57987    612                75459
# 7.615831    kworker/4:1      4    58479    612                75459
# 7.719753    kworker/4:1      4    59014    612                74026
# 7.819791    kworker/4:1      4    59510    612                73616
# 7.919806    kworker/4:1      4    60161    612                73002
# ...                 ...    ...      ...    ...                  ...
# 323.115767  kworker/4:1      4  1349449    612                78325
# 323.215767  kworker/4:1      4  1349463    612                78325
# 323.315784  kworker/4:1      4  1349477    612                78529
# 323.415751  kworker/4:1      4  1349493    612                78529
# 323.515766  kworker/4:1      4  1349519    612                78529
# 323.615765  kworker/4:1      4  1349535    612                78529
# 323.715766  kworker/4:1      4  1349555    612                78734
# 323.815783  kworker/4:1      4  1349569    612                78734
# 323.915766  kworker/4:1      4  1349583    612                78734
# 324.015765  kworker/4:1      4  1349597    612                78939
# 324.115766  kworker/4:1      4  1349611    612                78734
# 324.215784  kworker/4:1      4  1349625    612                78734
# 324.315763  kworker/4:1      4  1349639    612                78939
# 324.415799  kworker/4:1      4  1349697    612                79348
# 324.515811  kworker/4:1      4  1349725    612                77915
# 324.615764  kworker/4:1      4  1349751    612                78529
# 324.715766  kworker/4:1      4  1349769    612                78734
# 324.817618  kworker/4:1      4  1349871    612                77301
# 324.915947  kworker/4:1      4  1350199    612                75049
# 325.019804  kworker/4:1      4  1350586    612                74844
# 325.116394  kworker/4:1      4  1350996    612                73821
# 325.215840  kworker/4:1      4  1352247    612                75868
# 325.315922  kworker/4:1      4  1353648    612                80167
# 325.415886  kworker/4:1      4  1354989    612                77096
# 325.515828  kworker/4:1      4  1356420    612                77096
# 325.616050  kworker/4:1      4  1357364    612                76277
# 325.715842  kworker/4:1      4  1358178    612                76277
# 325.815872  kworker/4:1      4  1358453    612                72797
# 325.915774  kworker/4:1      4  1358859    612                72183
# 326.018933  kworker/4:1      4  1358920    612                70955
#
#             delta_temperature  granted_power0  granted_power1  granted_power2  \
# Time
# 3.999744                -3325             595             332            2046
# 4.100439               -11308               0               0               0
# 4.199914                  565             837             494            3533
# 4.299902                -2710             370             544            2200
# 4.399920                 -459             692             959            2468
# 4.503867                 -459             859             980            2274
# 4.603894                  -49             684             980            2635
# 4.703961                -2096             173             815            2370
# 4.803839                  974             924             980            3271
# 4.903913                 -459             396             827            2867
# 5.003857                 1384             908             558            4075
# 5.103859                -4553              56              27            2122
# 5.203800                -2710              87              50            2869
# 5.303893                 -663             230             121            3570
# 5.403912                 1179             813             112            4354
# 5.507768                 1793             201              72            5557
# 5.607850                 2203             528             176            5496
# 5.707896                 4864            1919             389            6284
# 6.807804                -5167              82              77            1969
# 6.907786                  565             137             664            4156
# 7.011768                 -459             219             438            3581
# 7.111850                  974             370              82            4869
# 7.211847                 1179             240             180            5084
# 7.311778                  -49             213              99            4110
# 7.415827                  770             212             606            4320
# 7.515817                 -459             187             589            3457
# 7.615831                 -459             211             105            3913
# 7.719753                  974             243             109            4959
# 7.819791                 1384             254             118            5309
# 7.919806                 1998             881             980            4369
# ...                       ...             ...             ...             ...
# 323.115767              -3325             101               0            2338
# 323.215767              -3325             100               0            2307
# 323.315784              -3529              95               0            2186
# 323.415751              -3529              93               0            2153
# 323.515766              -3529              92               0            2120
# 323.615765              -3529              90               0            2087
# 323.715766              -3734              85               0            1964
# 323.815783              -3734              84               0            1928
# 323.915766              -3734              82               0            1894
# 324.015765              -3939              77               0            1768
# 324.115766              -3734              79               0            1822
# 324.215784              -3734              77               0            1787
# 324.315763              -3939              72               0            1662
# 324.415799              -4348              64               2            1442
# 324.515811              -2915             114               0            2009
# 324.615764              -3529              75               0            1737
# 324.715766              -3734              70               0            1614
# 324.817618              -2301             153               5            2147
# 324.915947                -49             790             684            1842
# 325.019804                156            1248             980            1250
# 325.116394               1179            2138             980            1280
# 325.215840               -868             614             980            1346
# 325.315922              -5167             108             148             702
# 325.415886              -2096             517             452            1348
# 325.515828              -2096             681             329            1287
# 325.616050              -1277             537             206            1909
# 325.715842              -1277             609             391            1640
# 325.815872               2203            4620             490              85
# 325.915774               2817            3935             932             880
# 326.018933               4045            6036               0             816
#
#             max_allocatable_power  power_range  req_power0  req_power1  \
# Time
# 3.999744                    13700         2973          34          19
# 4.100439                    13749            0          44         401
# 4.199914                    13679         4865         105          62
# 4.299902                    13694         3113         212         312
# 4.399920                    13684         4119         244         338
# 4.503867                    13684         4115         237         475
# 4.603894                    13684         4299         126         411
# 4.703961                    13694         3359          87         409
# 4.803839                    13679         5176         144         323
# 4.903913                    13684         4090         137         286
# 5.003857                    13674         5541         161          99
# 5.103859                    13705         2206          35          17
# 5.203800                    13694         3007          33          19
# 5.303893                    13684         3921          72          38
# 5.403912                    13674         5279          87          12
# 5.507768                    13674         5831          39          14
# 5.607850                    13670         6200          39          13
# 5.707896                    13661         8593          26           8
# 6.807804                    13711         2128          36          34
# 6.907786                    13679         4957          29         141
# 7.011768                    13684         4238          38          76
# 7.111850                    13679         5321          45          10
# 7.211847                    13674         5505          28          21
# 7.311778                    13684         4422          30          14
# 7.415827                    13679         5137          29          83
# 7.515817                    13684         4233          43         135
# 7.615831                    13684         4229          30          15
# 7.719753                    13679         5311          29          13
# 7.819791                    13674         5680          28          13
# 7.919806                    13674         6232          28         178
# ...                           ...          ...         ...         ...
# 323.115767                  13700         2439          34           0
# 323.215767                  13700         2407          34           0
# 323.315784                  13700         2281          34           0
# 323.415751                  13700         2246          34           0
# 323.515766                  13700         2212          34           0
# 323.615765                  13700         2177          34           0
# 323.715766                  13700         2049          34           0
# 323.815783                  13700         2012          34           0
# 323.915766                  13700         1976          34           0
# 324.015765                  13700         1845          34           0
# 324.115766                  13700         1901          34           0
# 324.215784                  13700         1864          34           0
# 324.315763                  13700         1734          34           0
# 324.415799                  13705         1508          35           1
# 324.515811                  13694         2123          33           0
# 324.615764                  13700         1812          34           0
# 324.715766                  13700         1684          34           0
# 324.817618                  13694         2305          33           1
# 324.915947                  13684         3316          30          26
# 325.019804                  13679         3479          29         122
# 325.116394                  13674         4399          92         208
# 325.215840                  13684         2940         129         222
# 325.315922                  13711          958         162         222
# 325.415886                  13694         2317         158         138
# 325.515828                  13694         2297         236         114
# 325.616050                  13689         2652         172          66
# 325.715842                  13689         2640         220         141
# 325.815872                  13670         5195         217          23
# 325.915774                  13670         5747          76          18
# 326.018933                  13661         6852          74           0
#
#             req_power2  thermal_zone_id  total_granted_power  total_req_power
# Time
# 3.999744           235                0                 2973              288
# 4.100439          5294                0                    0             5739
# 4.199914           886                0                 4864             1053
# 4.299902          2524                0                 3114             3048
# 4.399920          1740                0                 4119             2322
# 4.503867          1530                0                 4113             2242
# 4.603894          1455                0                 4299             1992
# 4.703961          2379                0                 3358             2875
# 4.803839          1410                0                 5175             1877
# 4.903913          1985                0                 4090             2408
# 5.003857          1447                0                 5541             1707
# 5.103859          2639                0                 2205             2691
# 5.203800          2171                0                 3006             2223
# 5.303893          2240                0                 3921             2350
# 5.403912           932                0                 5279             1031
# 5.507768          2152                0                 5830             2205
# 5.607850           812                0                 6200              864
# 5.707896           510                0                 8592              544
# 6.807804          1728                0                 2128             1798
# 6.907786          1764                0                 4957             1934
# 7.011768          1242                0                 4238             1356
# 7.111850          1184                0                 5321             1239
# 7.211847          1184                0                 5504             1233
# 7.311778          1161                0                 4422             1205
# 7.415827          1184                0                 5138             1296
# 7.515817          1586                0                 4233             1764
# 7.615831          1114                0                 4229             1159
# 7.719753          1184                0                 5311             1226
# 7.819791          1172                0                 5681             1213
# 7.919806           828                0                 6230             1034
# ...                ...              ...                  ...              ...
# 323.115767        1571                0                 2439             1605
# 323.215767        1571                0                 2407             1605
# 323.315784        1571                0                 2281             1605
# 323.415751        1571                0                 2246             1605
# 323.515766        1571                0                 2212             1605
# 323.615765        1571                0                 2177             1605
# 323.715766        1571                0                 2049             1605
# 323.815783        1571                0                 2012             1605
# 323.915766        1571                0                 1976             1605
# 324.015765        1571                0                 1845             1605
# 324.115766        1571                0                 1901             1605
# 324.215784        1571                0                 1864             1605
# 324.315763        1571                0                 1734             1605
# 324.415799        1571                0                 1508             1607
# 324.515811        1161                0                 2123             1194
# 324.615764        1571                0                 1812             1605
# 324.715766        1571                0                 1684             1605
# 324.817618         926                0                 2305              960
# 324.915947         140                0                 3316              196
# 325.019804          60                0                 3478              211
# 325.116394          38                0                 4398              338
# 325.215840         578                0                 2940              929
# 325.315922        2105                0                  958             2489
# 325.415886         825                0                 2317             1121
# 325.515828         892                0                 2297             1242
# 325.616050        1222                0                 2652             1460
# 325.715842        1184                0                 2640             1545
# 325.815872           9                0                 5195              249
# 325.915774          35                0                 5747              129
# 326.018933          20                0                 6852               94
#
# [2728 rows x 17 columns]

# %%
import matplotlib.image as mpimg
import matplotlib.pyplot as plt

img=mpimg.imread( os.path.join(te.res_dir, 'screen.png'))
imgplot = plt.imshow(img)

# %%
target.execute('am force-stop com.antutu.ABenchMark')
target.execute('am force-stop com.antutu.benchmark.full')
# Out:
# ''
