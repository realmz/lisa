# %% [markdown]
# # GL benchmark on Android

# %% [markdown]
# The goal of this experiment is to run benchmarks on a hikey960 board running Android with an IPA kernel and collect results. The analysis phase will consist in comparing IPA summary with:
#
#
#
# The benchmark we will be using is ***GLbenchmark***. You will need to **manually install** the app on the Android device in order to run this Notebook.

# %%
import logging
from conf import LisaLogging
LisaLogging.setup()
# Out:
# 2018-05-09 18:19:21,943 INFO    : root         : Using LISA logging configuration:
# 2018-05-09 18:19:21,945 INFO    : root         :   /home/steven/lisa/lisa-github/logging.conf

# %%
# %pylab inline

import copy
import os
from time import sleep
from subprocess import Popen
import pandas as pd
import re

# Support to access the remote target
import devlib
from env import TestEnv

# Support for trace events analysis
from trace import Trace

# Suport for FTrace events parsing and visualization
import trappy
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /usr/local/lib/python2.7/dist-packages/IPython/core/magics/pylab.py:161: UserWarning: pylab import has clobbered these variables: ['copy']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# ## Test environment setup
#
# For more details on this please check out **examples/utils/testenv_example.ipynb**.

# %% [markdown]
# In case more than one Android device are conencted to the host, you must specify the ID of the device you want to target in `my_target_conf`. Run `adb devices` on your host to get the ID. Also, you have to specify the path to your android sdk in ANDROID_HOME.

# %%
# Setup a target configuration
androidsdk_path=os.path.join(os.getcwd(), "../../../android-sdk")

my_target_conf = {
    
#     # Target platform and board
#     "platform"    : 'android',

#     # Add target support
#     "board" : 'pixel',
    
#     # Device ID
#     "device" : "HT6670300102",
    
#     "ANDROID_HOME" : "/home/vagrant/lisa/tools/android-sdk-linux/",
    
    "platform"    : 'android',
    "board"       : "hikey960",
    "device" : "0123456789ABCDEF",
    
    "ANDROID_HOME" : androidsdk_path,
    "rtapp-calib" : {"0": 302, "1": 302, "2": 304, "3": 304, "4": 136, "5": 137, "6": 136, "7": 136},

     "emeter" : {
        "instrument" : "acme",
        "conf" : {
            # Absolute path to the iio-capture binary on the host
            'iio-capture' : '/usr/bin/iio-capture',
            # Default host name of the BeagleBone Black
            'ip_address'     : '10.169.36.36',
        },
        "channel_map" : {
            "Device0" : 0, # iio:device0
            "Device1" : 1, # iio:device0
        }
    },
    
    # FTrace events to collect for all the tests configuration which have
    # the "ftrace" flag enabled
    "ftrace"  : {
         "events" : [
            "cpu_frequency",
            "thermal_power_devfreq_limit",
            "thermal_power_devfreq_get_power",
            "thermal_power_cpu_limit",
            "thermal_power_cpu_get_power",
            "thermal_zone_trip",
            "cdev_update",
            "thermal_temperature",
            "thermal_power_allocator_pid",
            "thermal_power_allocator",
         ],
         "buffsize" : 100 * 1024,
    },

    # Tools required by the experiments
    "tools"   : [ 'trace-cmd', 'taskset', 'sysbench'],
    
    # Define devlib modules to load
    "modules"     : [
        'cpufreq',       # enable CPUFreq support
        'bl', 'cpufreq', 'cpuidle', 'hotplug', 'cgroups'
    ],
    "results_dir" : "power_virus3",
    
}

# %%
my_tests_conf = {

    # Folder where all the results will be collected

    # Platform configurations to test
    "confs" : [
        {
            "tag"            : "power_virus",
            "flags"          : "ftrace",           # Enable FTrace events
            "sched_features" : "ENERGY_AWARE",     # enable EAS
        },
    ],
}

# %%
# Initialize a test environment using:
# the provided target configuration (my_target_conf)
# the provided test configuration   (my_test_conf)
te = TestEnv(target_conf=my_target_conf, test_conf=my_tests_conf)
target = te.target
# Out:
# 2018-05-09 18:19:23,009 INFO    : TestEnv      : Using base path: /home/steven/lisa/lisa-github
# 2018-05-09 18:19:23,013 INFO    : TestEnv      : Loading custom (inline) target configuration
# 2018-05-09 18:19:23,015 INFO    : TestEnv      : Loading custom (inline) test configuration
# 2018-05-09 18:19:23,016 WARNING : TestEnv      : Wipe previous contents of the results folder:
# 2018-05-09 18:19:23,017 WARNING : TestEnv      :    /home/steven/lisa/lisa-github/results/power_virus3
# 2018-05-09 18:19:23,019 INFO    : TestEnv      : External tools using:
# 2018-05-09 18:19:23,020 INFO    : TestEnv      :    ANDROID_HOME: /home/steven/lisa/lisa-github/ipynb/ipa/../../../android-sdk
# 2018-05-09 18:19:23,022 INFO    : TestEnv      :    CATAPULT_HOME: /home/steven/lisa/lisa-github/tools/catapult
# 2018-05-09 18:19:23,023 INFO    : TestEnv      : Devlib modules to load: ['bl', 'cpuidle', 'cpufreq', 'cgroups', 'hotplug']
# 2018-05-09 18:19:23,025 INFO    : TestEnv      : Connecting Android target [0123456789ABCDEF]
# 2018-05-09 18:19:23,026 INFO    : TestEnv      : Connection settings:
# 2018-05-09 18:19:23,027 INFO    : TestEnv      :    {'device': '0123456789ABCDEF'}
# 2018-05-09 18:19:24,066 INFO    : TestEnv      : Initializing target workdir:
# 2018-05-09 18:19:24,068 INFO    : TestEnv      :    /data/local/tmp/devlib-target
# 2018-05-09 18:19:24,401 INFO    : CGroups      : Available controllers:
# 2018-05-09 18:19:24,549 INFO    : CGroups      :   cpuset       : /data/local/tmp/devlib-target/cgroups/devlib_cgh5
# 2018-05-09 18:19:24,695 INFO    : CGroups      :   cpu          : /data/local/tmp/devlib-target/cgroups/devlib_cgh4
# 2018-05-09 18:19:24,860 INFO    : CGroups      :   cpuacct      : /data/local/tmp/devlib-target/cgroups/devlib_cgh1
# 2018-05-09 18:19:24,994 INFO    : CGroups      :   schedtune    : /data/local/tmp/devlib-target/cgroups/devlib_cgh2
# 2018-05-09 18:19:25,119 INFO    : CGroups      :   blkio        : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:19:25,240 INFO    : CGroups      :   memory       : /data/local/tmp/devlib-target/cgroups/devlib_cgh3
# 2018-05-09 18:19:25,359 INFO    : CGroups      :   devices      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:19:25,496 INFO    : CGroups      :   freezer      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:19:25,631 INFO    : CGroups      :   hugetlb      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:19:25,761 INFO    : CGroups      :   debug        : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:19:26,905 INFO    : TestEnv      : Attempting to read energy model from target
# 2018-05-09 18:19:27,362 INFO    : TestEnv      : Topology:
# 2018-05-09 18:19:27,364 INFO    : TestEnv      :    [[0, 1, 2, 3], [4, 5, 6, 7]]
# 2018-05-09 18:19:27,426 INFO    : TestEnv      : Loading default EM:
# 2018-05-09 18:19:27,428 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/libs/utils/platforms/hikey960.json
# 2018-05-09 18:19:27,746 INFO    : TestEnv      : Enabled tracepoints:
# 2018-05-09 18:19:27,748 INFO    : TestEnv      :    cpu_frequency
# 2018-05-09 18:19:27,749 INFO    : TestEnv      :    thermal_power_devfreq_limit
# 2018-05-09 18:19:27,750 INFO    : TestEnv      :    thermal_power_devfreq_get_power
# 2018-05-09 18:19:27,751 INFO    : TestEnv      :    thermal_power_cpu_limit
# 2018-05-09 18:19:27,752 INFO    : TestEnv      :    thermal_power_cpu_get_power
# 2018-05-09 18:19:27,753 INFO    : TestEnv      :    thermal_zone_trip
# 2018-05-09 18:19:27,754 INFO    : TestEnv      :    cdev_update
# 2018-05-09 18:19:27,755 INFO    : TestEnv      :    thermal_temperature
# 2018-05-09 18:19:27,756 INFO    : TestEnv      :    thermal_power_allocator_pid
# 2018-05-09 18:19:27,757 INFO    : TestEnv      :    thermal_power_allocator
# 2018-05-09 18:19:27,758 INFO    : EnergyMeter  : ACME configuration:
# 2018-05-09 18:19:27,759 INFO    : EnergyMeter  :     binary: /usr/bin/iio-capture
# 2018-05-09 18:19:27,760 INFO    : EnergyMeter  :     device: 10.169.36.36
# 2018-05-09 18:19:27,761 INFO    : EnergyMeter  :   channels:
# 2018-05-09 18:19:27,762 INFO    : EnergyMeter  :      Device1 (iio:device1)
# 2018-05-09 18:19:27,763 INFO    : EnergyMeter  :      Device0 (iio:device0)
# 2018-05-09 18:19:27,776 INFO    : TestEnv      : Set results folder to:
# 2018-05-09 18:19:27,778 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/results/power_virus3
# 2018-05-09 18:19:27,779 INFO    : TestEnv      : Experiment results available also in:
# 2018-05-09 18:19:27,780 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/results_latest

# %% [markdown]
# # Workload configuration

# %%
import re
target.install_if_needed(os.path.join(te.LISA_HOME, 'tools/workload-automation/wa/./workloads/dhrystone/bin/arm64/dhrystone'))

class Dhrystone(object):
    """
    Sysbench benchmark class.
    
    :param duration: maximum workload duration in seconds
    :type duration: int
    """
    dhrystone_path = "/data/local/tmp/bin/dhrystone"
    
    def __init__(self, target, duration):
        self.target = target
        self.duration = duration

    def run(self, threads):
        """
        Run benchmark using the specified number of 'threads'
        to be executed under the specified 'cgroup'.
        
        :param cgroup: cgroup where to run the benchmark on
        :type cgroup: str
        
        :param threads: number of threads to spawn
        :type threads: int
        
        :returns: float - performance score
        """
        bench_out = self.target.execute(
            "{} -t 8 -r {}"
            .format(self.dhrystone_path, self.duration)
        )
        match = re.search(r'(Total dhrystone run time:\s*)([\d.]*)', bench_out)
        return float(match.group(2))

# %%
dhrystone = Dhrystone(target, 20)

# %% [markdown]
# ## Support Functions

# %% [markdown]
# This set of support functions will help us running the benchmark using different CPUFreq governors.

# %%
#Check if package si available on the device

def check_packages(pkgname):
    try:
        output = target.execute('pm list packages | grep -i {}'.format(pkgname))
        return output
    except Exception:
        raise RuntimeError('Package: [{}] not availabe on target'.format(pkgname))

# Check for specified PKG name being available on target
pkgname=check_packages('glbench').split(':')[1]
print pkgname
target.adb_root(force=True)
# Out:
# com.glbenchmark.glbenchmark27

# %%
# Function that helps run a Antutu experiment
from android import Screen
from devlib.utils.android import adb_command
import re
from subprocess import Popen, PIPE
import time

def benchmark_run(exp_dir):
    # Unlock device screen (assume no password required)
    target.execute('am force-stop {}'.format(pkgname))
    target.execute('input keyevent 82')
    Screen.set_brightness(target, auto=False, percent=0)
    target.clear_logcat()

    # Start PCMark on the target device
    target.execute('monkey --pct-syskeys 0 -p   com.glbenchmark.glbenchmark27  1')
#     Screen.set_orientation(target, auto=False, portrait=True)

    # Wait few seconds to make sure the app is loaded
    sleep(10)
    
    # Flush entire log
    target.execute('input keyevent KEYCODE_TAB')
    target.execute('input keyevent KEYCODE_TAB')
    target.execute('input keyevent KEYCODE_ENTER')
    target.execute('input tap 961 608')


    Screen.set_orientation(target, auto=False, portrait=True)
    # Run performance workload (assume screen is vertical)

    start_logline = r'ActivityManager: Displayed com.glbenchmark.glbenchmark27/net.kishonti.benchui.initialization.InitActivity'
    BENCHMARK_START_RE = re.compile(start_logline)
    end_logline = r'ActivityManager: *xyz'
    BENCHMARK_END_RE = re.compile(end_logline)
        
    logcat_cmd = 'adb -s {} shell logcat ActivityManager:* System.out:I *:S BENCH:*'\
                .format(target.adb_name)

    print logcat_cmd
        # Start the activity
    logcat = Popen(logcat_cmd, shell=True, stdout=PIPE)
    loop=0
    current=time.time()
    endtime = current + 20
    while True:

        # read next logcat line (up to max 1024 chars)
        message = logcat.stdout.readline(1024)

        loop=loop+1
        print message, loop
        print time.time()
        if BENCHMARK_START_RE.search(message):
        # Benchmark start trigger
            print("Benchmark started!")
            sleep(5)
            print("tap")
            print (time.time())
            target.execute('input tap 961 608')
            sleep(10)
            target.execute('input tap 180 1005')
            target.execute('input tap 958 571')
            dhrystone.run(8)
            print("Benchmark ended!")
            break
        elif time.time() > endtime:
            break
        else:         
            continue
    
    sleep(1)
    # Wait for completion (10 minutes in total) and collect log
#     log_file = os.path.join(exp_dir, 'log.txt')
    # Wait 5 minutes
    # Start collecting the log
#     with open(log_file, 'w') as log:
#         logcat = Popen(['adb logcat', 'com.antutu.ABenchMark.VirtualMachineState:*', '*:S'],
#                        stdout=log,
#                        shell=True)
#         # Wait additional two minutes for benchmark to complete
#         sleep(300)

#         # Terminate logcat
#         logcat.kill()

#     # Get scores from logcat
#     score_file = os.path.join(exp_dir, 'score.txt')
#     os.popen('grep -o ".*_SCORE .*" {} | sed "s/ = / /g" | sort -u > {}'.format(log_file, score_file))
    
    # Close application
    adb_command(target.adb_name, 'shell screencap -p /data/local/tmp/screen.png')
    adb_command(target.adb_name, 'pull /data/local/tmp/screen.png {}'.format(te.res_dir))
    target.execute('am force-stop {}'.format(pkgname))

# %%
# Function that helps run PCMark for different governors
# trace_file = os.path.join(te.res_dir, 'trace.txt')

def experiment(governor, exp_dir):
    logging.info('------------------------')
    logging.info('Run workload using %s governor', governor)
    ### Run the benchmark ###
    te.ftrace.start()

    benchmark_run(exp_dir)
    
    te.ftrace.stop()

    # return all the experiment data
    return {
        'dir'        : exp_dir,
    }

# %% [markdown]
# ## Run Antutu and collect scores

# %% [markdown]
# After running the benchmark for the specified governors we can show and plot the scores:

# %%
res = experiment('test', te.res_dir)
# Out:
# 2018-05-09 18:19:29,309 INFO    : root         : ------------------------
# 2018-05-09 18:19:29,311 INFO    : root         : Run workload using test governor
# 2018-05-09 18:19:36,074 INFO    : Screen       : Set brightness: 0%
# 2018-05-09 18:19:48,193 INFO    : Screen       : Force manual orientation
# 2018-05-09 18:19:48,195 INFO    : Screen       : Set orientation: PORTRAIT
# adb -s 0123456789ABCDEF shell logcat ActivityManager:* System.out:I *:S BENCH:*
# --------- beginning of system
# 1
# 1525861188.99
# 05-09 10:21:04.547  2297 15320 I ActivityManager: START u0 {act=android.intent.action.MAIN cat=[android.intent.category.LAUNCHER] flg=0x10200000 cmp=com.glbenchmark.glbenchmark27/net.kishonti.app.MainActivity} from uid 0 on display 0
# 2
# 1525861189.03
# --------- beginning of main
# 3
# 1525861189.03
# 05-09 10:21:04.602  2297  2327 I ActivityManager: Start proc 15250:com.glbenchmark.glbenchmark27/u0a57 for activity com.glbenchmark.glbenchmark27/net.kishonti.app.MainActivity
# 4
# 1525861189.03
# 05-09 10:21:04.602  2297  2327 W ActivityManager: Slow operation: 51ms so far, now at startProcess: done starting proc!
# 5
# 1525861189.03
# 05-09 10:21:04.763  2297  4919 I ActivityManager: START u0 {flg=0x10000000 cmp=com.glbenchmark.glbenchmark27/net.kishonti.benchui.initialization.InitActivity} from uid 10057 on display 0
# 6
# 1525861189.03
# 05-09 10:21:05.203  2297  2319 I ActivityManager: Displayed com.glbenchmark.glbenchmark27/net.kishonti.benchui.initialization.InitActivity: +253ms (total +651ms)
# 7
# 1525861189.03
# Benchmark started!
# tap
# 1525861194.04
# Benchmark ended!

# %%
te.ftrace.get_trace(os.path.join(te.res_dir, 'trace.dat'))

# %%
map_label = {"00000000,000000f0": "big", "00000000,0000000f": "LITTLE"}
actor_order = ["GPU", "big", "LITTLE"]

# %%
# !tree {te.res_dir}
# Out:
# /home/steven/lisa/lisa-github/results/power_virus3
# ├── screen.png
# └── trace.dat
#
# 0 directories, 2 files

# %%
trappy.summary_plots(actor_order, map_label, path=os.path.join(te.res_dir, 'trace.dat'))

# %%
target.install_if_needed(os.path.join(te.LISA_HOME, 'tools/workload-automation/wa/./workloads/dhrystone/bin/arm64/dhrystone'))
# Out:
# '/data/local/tmp/bin/dhrystone'
