# %% [markdown]
# # GL benchmark on Android

# %% [markdown]
# The goal of this experiment is to run benchmarks on a hikey960 board running Android with an IPA kernel and collect results. The analysis phase will consist in comparing IPA summary with:
#
#
#
# The benchmark we will be using is ***GLbenchmark***. You will need to **manually install** the app on the Android device in order to run this Notebook.

# %%
import logging
from conf import LisaLogging
LisaLogging.setup()
# Out:
# 2018-05-09 18:26:26,341 INFO    : root         : Using LISA logging configuration:
# 2018-05-09 18:26:26,343 INFO    : root         :   /home/steven/lisa/lisa-github/logging.conf

# %%
# %pylab inline

import copy
import os
from time import sleep
from subprocess import Popen
import pandas as pd
import re


# Support to access the remote target
import devlib
from env import TestEnv

# Support for trace events analysis
from trace import Trace

# Suport for FTrace events parsing and visualization
import trappy
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ## Test environment setup
#
# For more details on this please check out **examples/utils/testenv_example.ipynb**.

# %% [markdown]
# In case more than one Android device are conencted to the host, you must specify the ID of the device you want to target in `my_target_conf`. Run `adb devices` on your host to get the ID. Also, you have to specify the path to your android sdk in ANDROID_HOME.

# %%
# Setup a target configuration
androidsdk_path=os.path.join(os.getcwd(), "../../../android-sdk")

my_target_conf = {
    
#     # Target platform and board
#     "platform"    : 'android',

#     # Add target support
#     "board" : 'pixel',
    
#     # Device ID
#     "device" : "HT6670300102",
    
#     "ANDROID_HOME" : "/home/vagrant/lisa/tools/android-sdk-linux/",
    
    "platform"    : 'android',
    "board"       : "hikey960",
    "device" : "0123456789ABCDEF",
    
    "ANDROID_HOME" : androidsdk_path,
    "rtapp-calib" : {"0": 302, "1": 302, "2": 304, "3": 304, "4": 136, "5": 137, "6": 136, "7": 136},

     "emeter" : {
        "instrument" : "acme",
        "conf" : {
            # Absolute path to the iio-capture binary on the host
            'iio-capture' : '/usr/bin/iio-capture',
            # Default host name of the BeagleBone Black
            'ip_address'     : '10.169.36.36',
        },
        "channel_map" : {
            "Device0" : 0, # iio:device0
            "Device1" : 1, # iio:device0
        }
    },
    
    # FTrace events to collect for all the tests configuration which have
    # the "ftrace" flag enabled
    "ftrace"  : {
         "events" : [
            "cpu_capacity",
            "cpu_frequency",
            "thermal_power_devfreq_limit",
            "thermal_power_devfreq_get_power",
            "thermal_power_cpu_limit",
            "thermal_power_cpu_get_power",
            "thermal_zone_trip",
            "cdev_update",
            "thermal_temperature",
            "thermal_power_allocator_pid",
            "thermal_power_allocator",
         ],
         "buffsize" : 100 * 1024,
    },

    # Tools required by the experiments
    "tools"   : [ 'trace-cmd', 'taskset', 'sysbench'],
    
    # Define devlib modules to load
    "modules"     : [
        'cpufreq',       # enable CPUFreq support
        'bl', 'cpufreq', 'cpuidle', 'hotplug', 'cgroups'
    ],
    "results_dir" : "power_virus2",

}

# %%
my_tests_conf = {

    # Folder where all the results will be collected

    # Platform configurations to test
    "confs" : [
        {
            "tag"            : "power_virus",
            "flags"          : "ftrace",           # Enable FTrace events
            "sched_features" : "ENERGY_AWARE",     # enable EAS
        },
    ],
}

# %%
# Initialize a test environment using:
# the provided target configuration (my_target_conf)
# the provided test configuration   (my_test_conf)
te = TestEnv(target_conf=my_target_conf, test_conf=my_tests_conf)
target = te.target
# Out:
# 2018-05-09 18:26:27,955 INFO    : TestEnv      : Using base path: /home/steven/lisa/lisa-github
# 2018-05-09 18:26:27,957 INFO    : TestEnv      : Loading custom (inline) target configuration
# 2018-05-09 18:26:27,958 INFO    : TestEnv      : Loading custom (inline) test configuration
# 2018-05-09 18:26:27,959 WARNING : TestEnv      : Wipe previous contents of the results folder:
# 2018-05-09 18:26:27,960 WARNING : TestEnv      :    /home/steven/lisa/lisa-github/results/power_virus2
# 2018-05-09 18:26:27,963 INFO    : TestEnv      : External tools using:
# 2018-05-09 18:26:27,965 INFO    : TestEnv      :    ANDROID_HOME: /home/steven/lisa/lisa-github/ipynb/ipa/../../../android-sdk
# 2018-05-09 18:26:27,966 INFO    : TestEnv      :    CATAPULT_HOME: /home/steven/lisa/lisa-github/tools/catapult
# 2018-05-09 18:26:27,967 INFO    : TestEnv      : Devlib modules to load: ['bl', 'cpuidle', 'cpufreq', 'cgroups', 'hotplug']
# 2018-05-09 18:26:27,968 INFO    : TestEnv      : Connecting Android target [0123456789ABCDEF]
# 2018-05-09 18:26:27,969 INFO    : TestEnv      : Connection settings:
# 2018-05-09 18:26:27,970 INFO    : TestEnv      :    {'device': '0123456789ABCDEF'}
# 2018-05-09 18:26:29,021 INFO    : TestEnv      : Initializing target workdir:
# 2018-05-09 18:26:29,023 INFO    : TestEnv      :    /data/local/tmp/devlib-target
# 2018-05-09 18:26:29,227 INFO    : CGroups      : Available controllers:
# 2018-05-09 18:26:29,324 INFO    : CGroups      :   cpuset       : /data/local/tmp/devlib-target/cgroups/devlib_cgh5
# 2018-05-09 18:26:29,430 INFO    : CGroups      :   cpu          : /data/local/tmp/devlib-target/cgroups/devlib_cgh4
# 2018-05-09 18:26:29,558 INFO    : CGroups      :   cpuacct      : /data/local/tmp/devlib-target/cgroups/devlib_cgh1
# 2018-05-09 18:26:29,868 INFO    : CGroups      :   schedtune    : /data/local/tmp/devlib-target/cgroups/devlib_cgh2
# 2018-05-09 18:26:29,979 INFO    : CGroups      :   blkio        : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:26:30,093 INFO    : CGroups      :   memory       : /data/local/tmp/devlib-target/cgroups/devlib_cgh3
# 2018-05-09 18:26:30,254 INFO    : CGroups      :   devices      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:26:30,432 INFO    : CGroups      :   freezer      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:26:30,595 INFO    : CGroups      :   hugetlb      : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:26:30,746 INFO    : CGroups      :   debug        : /data/local/tmp/devlib-target/cgroups/devlib_cgh6
# 2018-05-09 18:26:31,900 INFO    : TestEnv      : Attempting to read energy model from target
# 2018-05-09 18:26:32,616 INFO    : TestEnv      : Topology:
# 2018-05-09 18:26:32,618 INFO    : TestEnv      :    [[0, 1, 2, 3], [4, 5, 6, 7]]
# 2018-05-09 18:26:32,724 INFO    : TestEnv      : Loading default EM:
# 2018-05-09 18:26:32,726 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/libs/utils/platforms/hikey960.json
# 2018-05-09 18:26:33,107 INFO    : TestEnv      : Enabled tracepoints:
# 2018-05-09 18:26:33,109 INFO    : TestEnv      :    cpu_capacity
# 2018-05-09 18:26:33,110 INFO    : TestEnv      :    cpu_frequency
# 2018-05-09 18:26:33,112 INFO    : TestEnv      :    thermal_power_devfreq_limit
# 2018-05-09 18:26:33,113 INFO    : TestEnv      :    thermal_power_devfreq_get_power
# 2018-05-09 18:26:33,114 INFO    : TestEnv      :    thermal_power_cpu_limit
# 2018-05-09 18:26:33,116 INFO    : TestEnv      :    thermal_power_cpu_get_power
# 2018-05-09 18:26:33,117 INFO    : TestEnv      :    thermal_zone_trip
# 2018-05-09 18:26:33,119 INFO    : TestEnv      :    cdev_update
# 2018-05-09 18:26:33,120 INFO    : TestEnv      :    thermal_temperature
# 2018-05-09 18:26:33,122 INFO    : TestEnv      :    thermal_power_allocator_pid
# 2018-05-09 18:26:33,123 INFO    : TestEnv      :    thermal_power_allocator
# 2018-05-09 18:26:33,124 INFO    : EnergyMeter  : ACME configuration:
# 2018-05-09 18:26:33,126 INFO    : EnergyMeter  :     binary: /usr/bin/iio-capture
# 2018-05-09 18:26:33,127 INFO    : EnergyMeter  :     device: 10.169.36.36
# 2018-05-09 18:26:33,128 INFO    : EnergyMeter  :   channels:
# 2018-05-09 18:26:33,130 INFO    : EnergyMeter  :      Device1 (iio:device1)
# 2018-05-09 18:26:33,131 INFO    : EnergyMeter  :      Device0 (iio:device0)
# 2018-05-09 18:26:33,145 INFO    : TestEnv      : Set results folder to:
# 2018-05-09 18:26:33,148 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/results/power_virus2
# 2018-05-09 18:26:33,150 INFO    : TestEnv      : Experiment results available also in:
# 2018-05-09 18:26:33,151 INFO    : TestEnv      :    /home/steven/lisa/lisa-github/results_latest

# %% [markdown]
# # Workload configuration

# %%
# Support to configure and run RTApp based workloads
from wlgen import RTA, Periodic, Ramp

# Create a new RTApp workload generator using the calibration values
# reported by the TestEnv module
rtapp = RTA(target, 'simple', calibration=te.calibration())
duration=10

# Configure this RTApp instance to:
rtapp.conf(
    # 1. generate a "profile based" set of tasks
    kind='profile',
    
    # 2. define the "profile" of each task
    params={
        
        'stp_0': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration
        ).get(),
        'stp_1': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration
        ).get(),
        'stp_2': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration    
        ).get(),
        'stp_3': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration    
        ).get(),
        'stp_4': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration
        ).get(),
        'stp_5': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration    
        ).get(),
        'stp_6': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration    
        ).get(),
        'stp_7': Periodic(
            period_ms=100,         # period
            duty_cycle_pct=100,     # duty cycle
            duration_s=duration,          # duration    
        ).get(),
    },
    
    # 4. use this folder for task logfiles
    run_dir=target.working_directory
    
);
# Out:
# 2018-05-09 18:26:33,204 INFO    : Workload     : Setup new workload simple
# 2018-05-09 18:26:33,253 INFO    : Workload     : Workload duration defined by longest task
# 2018-05-09 18:26:33,255 INFO    : Workload     : Default policy: SCHED_OTHER
# 2018-05-09 18:26:33,257 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,259 INFO    : Workload     : task [stp_0], sched: using default policy
# 2018-05-09 18:26:33,260 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,262 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,264 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,265 INFO    : Workload     : task [stp_1], sched: using default policy
# 2018-05-09 18:26:33,267 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,268 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,272 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,274 INFO    : Workload     : task [stp_2], sched: using default policy
# 2018-05-09 18:26:33,275 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,276 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,277 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,278 INFO    : Workload     : task [stp_3], sched: using default policy
# 2018-05-09 18:26:33,280 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,281 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,283 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,285 INFO    : Workload     : task [stp_4], sched: using default policy
# 2018-05-09 18:26:33,287 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,289 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,290 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,292 INFO    : Workload     : task [stp_5], sched: using default policy
# 2018-05-09 18:26:33,293 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,294 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,296 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,297 INFO    : Workload     : task [stp_6], sched: using default policy
# 2018-05-09 18:26:33,299 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,300 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]
# 2018-05-09 18:26:33,302 INFO    : Workload     : ------------------------
# 2018-05-09 18:26:33,303 INFO    : Workload     : task [stp_7], sched: using default policy
# 2018-05-09 18:26:33,305 INFO    : Workload     :  | loops count: 1
# 2018-05-09 18:26:33,309 INFO    : Workload     :  + phase_000001: batch 10.000000 [s]

# %%
class Sysbench(object):
    """
    Sysbench benchmark class.
    
    :param duration: maximum workload duration in seconds
    :type duration: int
    """
    sysbench_path = "/data/local/tmp/bin/sysbench"
    
    def __init__(self, target, duration):
        self.target = target
        self.duration = duration

    def run(self, threads):
        """
        Run benchmark using the specified number of 'threads'
        to be executed under the specified 'cgroup'.
        
        :param cgroup: cgroup where to run the benchmark on
        :type cgroup: str
        
        :param threads: number of threads to spawn
        :type threads: int
        
        :returns: float - performance score
        """
        bench_out = self.target.execute(
            "{} --test=cpu --num-threads={} --max-time={} run"
            .format(self.sysbench_path, threads, self.duration)
        )
        match = re.search(r'(total number of events:\s*)([\d.]*)', bench_out)
        return float(match.group(2))

# %% [markdown]
# ## Support Functions

# %% [markdown]
# This set of support functions will help us running the benchmark using different CPUFreq governors.

# %%
#Check if package si available on the device

def check_packages(pkgname):
    try:
        output = target.execute('pm list packages | grep -i {}'.format(pkgname))
        return output
    except Exception:
        raise RuntimeError('Package: [{}] not availabe on target'.format(pkgname))

# Check for specified PKG name being available on target
pkgname=check_packages('glbench').split(':')[1]
print pkgname
target.adb_root(force=True)
# Out:
# com.glbenchmark.glbenchmark27

# %%
# Function that helps run a Antutu experiment
from android import Screen
from devlib.utils.android import adb_command
import re
from subprocess import Popen, PIPE
import time

sysbench = Sysbench(target, 30)

def benchmark_run(exp_dir):
    # Unlock device screen (assume no password required)
    target.execute('am force-stop {}'.format(pkgname))
    target.execute('input keyevent 82')
    Screen.set_brightness(target, auto=False, percent=0)
    target.clear_logcat()

    # Start PCMark on the target device
    target.execute('monkey --pct-syskeys 0 -p   com.glbenchmark.glbenchmark27  1')
#     Screen.set_orientation(target, auto=False, portrait=True)

    # Wait few seconds to make sure the app is loaded
    sleep(10)
    
    # Flush entire log

    Screen.set_orientation(target, auto=False, portrait=True)
    # Run performance workload (assume screen is vertical)

    start_logline = r'ActivityManager: Displayed com.glbenchmark.glbenchmark27/net.kishonti.benchui.initialization.InitActivity'
    BENCHMARK_START_RE = re.compile(start_logline)
    end_logline = r'ActivityManager: *xyz'
    BENCHMARK_END_RE = re.compile(end_logline)
        
    logcat_cmd = 'adb -s {} shell logcat ActivityManager:* System.out:I *:S BENCH:*'\
                .format(target.adb_name)

    print logcat_cmd
        # Start the activity
    logcat = Popen(logcat_cmd, shell=True, stdout=PIPE)
    loop=0
    current=time.time()
    endtime = current + 30
    while True:

        # read next logcat line (up to max 1024 chars)
        message = logcat.stdout.readline(1024)

        loop=loop+1
        print message, loop
        print time.time()
        # Benchmark start trigger
        if BENCHMARK_START_RE.search(message):
            print("Benchmark started!")
            sleep(5)
            print("tap")
            print (time.time())
            target.execute('input tap 961 608')
            sleep(20)
            print (time.time())
            target.execute('input tap 180 1005')
            target.execute('input tap 958 571')
            print (time.time())
            sysbench.run(8)
            sleep(10)
            print (time.time())
            print("Benchmark ended!")
            break
        elif time.time() > endtime:
            break
        else:         
            continue
    
    sleep(1)
    # Wait for completion (10 minutes in total) and collect log
#     log_file = os.path.join(exp_dir, 'log.txt')
    # Wait 5 minutes
    # Start collecting the log
#     with open(log_file, 'w') as log:
#         logcat = Popen(['adb logcat', 'com.antutu.ABenchMark.VirtualMachineState:*', '*:S'],
#                        stdout=log,
#                        shell=True)
#         # Wait additional two minutes for benchmark to complete
#         sleep(300)

#         # Terminate logcat
#         logcat.kill()

#     # Get scores from logcat
#     score_file = os.path.join(exp_dir, 'score.txt')
#     os.popen('grep -o ".*_SCORE .*" {} | sed "s/ = / /g" | sort -u > {}'.format(log_file, score_file))
    
    # Close application
    adb_command(target.adb_name, 'shell screencap -p /data/local/tmp/screen.png')
    adb_command(target.adb_name, 'pull /data/local/tmp/screen.png {}'.format(te.res_dir))
    target.execute('am force-stop {}'.format(pkgname))

# %%
# Function that helps run PCMark for different governors
# trace_file = os.path.join(te.res_dir, 'trace.txt')

def experiment(governor, exp_dir):
    logging.info('------------------------')
    logging.info('Run workload using %s governor', governor)
    ### Run the benchmark ###
    te.ftrace.start()

    benchmark_run(exp_dir)
    
    te.ftrace.stop()

    # return all the experiment data
    return {
        'dir'        : exp_dir,
    }

# %% [markdown]
# ## Run Antutu and collect scores

# %%
## Run the benchmark in all the configured governors

res = experiment('test', te.res_dir)
# Out:
# 2018-05-09 18:26:34,688 INFO    : root         : ------------------------
# 2018-05-09 18:26:34,690 INFO    : root         : Run workload using test governor
# 2018-05-09 18:26:39,884 INFO    : Screen       : Set brightness: 0%
# 2018-05-09 18:26:50,409 INFO    : Screen       : Force manual orientation
# 2018-05-09 18:26:50,411 INFO    : Screen       : Set orientation: PORTRAIT
# adb -s 0123456789ABCDEF shell logcat ActivityManager:* System.out:I *:S BENCH:*
# --------- beginning of main
# 1
# 1525861611.18
# --------- beginning of system
# 2
# 1525861611.22
# 05-09 10:28:05.515  2297  4919 I ActivityManager: Process com.android.bluetooth (pid 13828) has died
# 3
# 1525861611.22
# 05-09 10:28:05.515  2297  4919 D ActivityManager: cleanUpApplicationRecord -- 13828
# 4
# 1525861611.22
# 05-09 10:28:05.515  2297  4919 W ActivityManager: Service crashed 2 times, stopping: ServiceRecord{57b8c70 u0 com.android.bluetooth/.btservice.AdapterService}
# 5
# 1525861611.22
# 05-09 10:28:05.515  2297  4919 W ActivityManager: Scheduling restart of crashed service com.android.bluetooth/.gatt.GattService in 1000ms
# 6
# 1525861611.22
# 05-09 10:28:05.510  2297  2297 I ActivityManager: type=1400 audit(0.0:990): avc: denied { getpgid } for scontext=u:r:system_server:s0 tcontext=u:r:bluetooth:s0 tclass=process permissive=1
# 7
# 1525861611.22
# 05-09 10:28:05.749  2297  2318 I ActivityManager: Start proc 13874:com.android.bluetooth/1002 for service com.android.bluetooth/.btservice.AdapterService
# 8
# 1525861611.22
# --------- beginning of crash
# 9
# 1525861611.23
# 05-09 10:28:06.562  2297 10591 I ActivityManager: Process com.android.bluetooth (pid 13874) has died
# 10
# 1525861611.23
# 05-09 10:28:06.562  2297 10591 D ActivityManager: cleanUpApplicationRecord -- 13874
# 11
# 1525861611.23
# 05-09 10:28:06.563  2297 10591 W ActivityManager: Scheduling restart of crashed service com.android.bluetooth/.btservice.AdapterService in 1000ms
# 12
# 1525861611.23
# 05-09 10:28:06.563  2297 10591 W ActivityManager: Scheduling restart of crashed service com.android.bluetooth/.gatt.GattService in 11000ms
# 13
# 1525861611.23
# 05-09 10:28:06.786  2297  2318 I ActivityManager: Start proc 13946:com.android.bluetooth/1002 for service com.android.bluetooth/.btservice.AdapterService
# 14
# 1525861611.23
# 05-09 10:28:06.882  2297  3349 I ActivityManager: Force stopping com.glbenchmark.glbenchmark27 appid=10057 user=0: from pid 13945
# 15
# 1525861611.23
# 05-09 10:28:07.606  2297  3349 I ActivityManager: Process com.android.bluetooth (pid 13946) has died
# 16
# 1525861611.23
# 05-09 10:28:07.606  2297  3349 D ActivityManager: cleanUpApplicationRecord -- 13946
# 17
# 1525861611.23
# 05-09 10:28:07.606  2297  3349 W ActivityManager: Service crashed 2 times, stopping: ServiceRecord{c435932 u0 com.android.bluetooth/.btservice.AdapterService}
# 18
# 1525861611.23
# 05-09 10:28:07.607  2297  3349 W ActivityManager: Scheduling restart of crashed service com.android.bluetooth/.gatt.GattService in 1000ms
# 19
# 1525861611.23
# 05-09 10:28:07.819  2297  2318 I ActivityManager: Start proc 14019:com.android.bluetooth/1002 for service com.android.bluetooth/.btservice.AdapterService
# 20
# 1525861611.23
# 05-09 10:28:08.364  2297  3637 I ActivityManager: START u0 {act=android.intent.action.MAIN cat=[android.intent.category.LAUNCHER] flg=0x10200000 cmp=com.glbenchmark.glbenchmark27/net.kishonti.app.MainActivity} from uid 0 on display 0
# 21
# 1525861611.23
# 05-09 10:28:08.417  2297  3349 I ActivityManager: Start proc 14079:com.glbenchmark.glbenchmark27/u0a57 for activity com.glbenchmark.glbenchmark27/net.kishonti.app.MainActivity
# 22
# 1525861611.23
# 05-09 10:28:08.620  2297  3637 I ActivityManager: START u0 {flg=0x10000000 cmp=com.glbenchmark.glbenchmark27/net.kishonti.benchui.initialization.InitActivity} from uid 10057 on display 0
# 23
# 1525861611.23
# 05-09 10:28:08.827  2297  3349 I ActivityManager: Process com.android.bluetooth (pid 14019) has died
# 24
# 1525861611.23
# 05-09 10:28:08.827  2297  3349 D ActivityManager: cleanUpApplicationRecord -- 14019
# 25
# 1525861611.23
# 05-09 10:28:08.827  2297  3349 W ActivityManager: Scheduling restart of crashed service com.android.bluetooth/.btservice.AdapterService in 1000ms
# 26
# 1525861611.23
# 05-09 10:28:08.827  2297  3349 W ActivityManager: Scheduling restart of crashed service com.android.bluetooth/.gatt.GattService in 11000ms
# 27
# 1525861611.23
# 05-09 10:28:09.043  2297  2318 I ActivityManager: Start proc 14125:com.android.bluetooth/1002 for service com.android.bluetooth/.btservice.AdapterService
# 28
# 1525861611.24
# 05-09 10:28:09.192  2297  2319 I ActivityManager: Displayed com.glbenchmark.glbenchmark27/net.kishonti.benchui.initialization.InitActivity: +209ms (total +823ms)
# 29
# 1525861611.24
# Benchmark started!
# tap
# 1525861616.24
# 1525861636.61
# 1525861637.32
# 1525861653.38
# Benchmark ended!

# %% [markdown]
# After running the benchmark for the specified governors we can show and plot the scores:

# %%
te.ftrace.get_trace(os.path.join(te.res_dir, 'trace.dat'))

# %%
map_label = {"00000000,000000f0": "big", "00000000,0000000f": "LITTLE"}
actor_order = ["GPU", "big", "LITTLE"]

# %%
# !tree {te.res_dir}
# Out:
# /home/steven/lisa/lisa-github/results/power_virus2
# ├── screen.png
# └── trace.dat
#
# 0 directories, 2 files

# %%
trappy.summary_plots(actor_order, map_label, path=os.path.join(te.res_dir, 'trace.dat'))
